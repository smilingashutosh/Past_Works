# %% [markdown]
# <a href="https://colab.research.google.com/github/smilingashutosh/Visualization_summ/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Start the Visualization

# %%
# generate the data points

import numpy as np
import matplotlib.pyplot as plt
# print(X)
# print(s)
plt.figure(figsize=(8,6),dpi=100)
X = np.linspace(-np.pi,np.pi,256)
s,c = np.sin(X),np.cos(X)
plt.plot(X,s,c='b',linewidth=1.0,linestyle='--')
plt.plot(X,c,c='r')
plt.xlim(-4,4)
plt.xticks(np.linspace(-4,4,9,endpoint=True))
plt.ylim(-1,1)
plt.yticks([-1,0,1])
plt.savefig("foo1.png",dpi=72)

# %%
import numpy as np
import matplotlib.pyplot as plt
# print(X)
# print(s)
plt.figure(figsize=(8,6),dpi=100)
X = np.linspace(-np.pi,np.pi,256)
s,c = np.sin(X),np.cos(X)
plt.subplot(2,1,1)
plt.plot(X,s,c='b',linewidth=1.0,linestyle='--')
plt.subplot(2,1,2)
plt.plot(X,c,c='r')
plt.xlim(-4,4)
plt.xticks(np.linspace(-4,4,9,endpoint=True))
plt.ylim(-1,1)
plt.yticks([-1,0,1])
plt.savefig("foo1.png",dpi=72)

# %%
import numpy as np
import matplotlib.pyplot as plt
# print(X)
# print(s)
plt.figure(figsize=(8,6),dpi=100)
X = np.linspace(-np.pi,np.pi,256)
s,c = np.sin(X),np.cos(X)
plt.subplot(1,2,1)
plt.plot(X,s,c='b',linewidth=1.0,linestyle='--')
plt.subplot(1,2,2)
plt.plot(X,c,c='r')
plt.xlim(-4,4)
plt.xticks(np.linspace(-4,4,9,endpoint=True))
plt.ylim(-1,1)
plt.yticks([-1,0,1])
plt.savefig("foo1.png",dpi=72)

# %%
import numpy as np
import matplotlib.pyplot as plt
# print(X)
# print(s)
plt.figure(figsize=(8,6),dpi=100)
X = np.linspace(-np.pi,np.pi,256)
s,c = np.sin(X),np.cos(X)
plt.axes([0.1,0.5,0.1,0.5])
plt.plot(X,s,c='b',linewidth=1.0,linestyle='--')
plt.axes([0.6,0.8,0.6,0.8])
plt.plot(X,c,c='r')
plt.xlim(-4,4)
plt.xticks(np.linspace(-4,4,9,endpoint=True))
plt.ylim(-1,1)
plt.yticks([-1,0,1])
plt.savefig("foo1.png",dpi=72)
